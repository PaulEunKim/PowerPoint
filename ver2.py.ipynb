# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import ColorFormat, RGBColor


praise_path = './찬송가/'
praise_path += input("찬양(Praise)(장)?: ")
praise_path += '.pptx'

prs = Presentation(praise_path)

slide_count = len(prs.slides)
for n in range(slide_count):
    slide = prs.slides[n]
    img_path = 'bible.png'
    shapes = slide.shapes
    left = top = Inches(0)
    pic = shapes.add_picture(img_path, left, top) 
    shapes._spTree.remove(pic._element)
    shapes._spTree.insert(2, pic._element) # It makes picture backward


#slide = prs.slides[slide_count-1]

#prs = Presentation()

############0 표지
title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout) # add slide
img_path = 'slide0.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide1.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout) 
img_path = 'slide2.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout) 
img_path = 'slide3.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 


############1 찬양

#prs = Presentation('./찬송가/6장.pptx')
#slide = prs.slides[0]


############2 교독문
title_slide_layout = prs.slide_layouts[1]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'backGround2.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

title = slide.shapes.title
tf = title.text_frame
tfp = tf.add_paragraph()
tfp.font.size = Pt(50)
tfp.font.bold = False
tfp.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run = tfp.add_run()
font = run.font
font.name = 'Gungsuh'
run.text = "성시교독"

subtitle1 = slide.placeholders[0]
tf1 = subtitle1.text_frame
tfp1 = tf1.add_paragraph()
tfp1.font.size = Pt(36)
tfp1.font.bold = True
tfp1.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run1 = tfp1.add_run()
font1 = run1.font
font1.name = 'Gungsuh'

subtitle2 = slide.placeholders[0]
tf2 = subtitle2.text_frame
tfp2 = tf2.add_paragraph()
tfp2.font.size = Pt(36)
tfp2.font.bold = False
tfp2.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run2 = tfp2.add_run()
font2 = run2.font
font2.name = 'Gungsuh'

run1.text = "교독문 20 (시편 20편)"
run2.text = "\n어찌하여 이방 나라들이"

# Next slide
title_slide_layout = prs.slide_layouts[1]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'backGround2.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

subtitle = slide.placeholders[1]
tf2 = subtitle.text_frame
tfp2 = tf2.add_paragraph()
tfp2.font.size = Pt(36)
tfp2.font.bold = True
tfp2.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run2 = tfp2.add_run()
font2 = run2.font
font2.name = 'Gungsuh'


############3 신앙고백

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide4.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide5.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'bible.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 


############1 기도
title_slide_layout = prs.slide_layouts[2]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'pray.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

title = slide.shapes.title
tf = title.text_frame
tfp = tf.add_paragraph()
tfp.font.size = Pt(52)
tfp.font.bold = False
tfp.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)

run = tfp.add_run()
font = run.font
font.name = 'Gungsuh'
#run.text = "기도\n\n 김광수 집사"

run.text = "기도\n\n"
run.text += input("기도누구(Prayer): ")


############2 성경봉독
title_slide_layout = prs.slide_layouts[5]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'bible.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

title = slide.shapes.title
tf = title.text_frame
tfp = tf.add_paragraph()
tfp.font.size = Pt(52)
tfp.font.bold = False
tfp.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run = tfp.add_run()
font = run.font
font.name = 'Gungsuh'
run.text = "성경봉독\n"

title1 = slide.shapes.title
tf1 = title1.text_frame
tfp1 = tf1.add_paragraph()
tfp1.font.size = Pt(45)
tfp1.font.bold = True
tfp1.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run1 = tfp1.add_run()
font1 = run1.font
font1.name = 'Gungsuh'

title2 = slide.shapes.title
tf2 = title2.text_frame
tfp2 = tf2.add_paragraph()
tfp2.font.size = Pt(40)
tfp2.font.bold = True
tfp2.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run2 = tfp2.add_run()
font2 = run2.font
font2.name = 'Dotum'

#run1.text = "사도행전 4: 23~31\n(Acts)\n"
#run2.text = "장순영 집사"

run1.text = input("말씀본문(Bible): ")
run1.text += "\n("
run1.text += input("영어표기(English name): ")
run1.text += ")\n"
bibleWhere = str(run1.text)

run2.text = input("말씀봉독자(Reader): ")

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'bible.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide8.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

############3 성경강론
title_slide_layout = prs.slide_layouts[5]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'bible.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

title = slide.shapes.title
tf = title.text_frame
tfp = tf.add_paragraph()
tfp.font.size = Pt(49)
tfp.font.bold = False
tfp.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run = tfp.add_run()
font = run.font
font.name = 'Gungsuh'
run.text = "성경강론\n"

title1 = slide.shapes.title
tf1 = title1.text_frame
tfp1 = tf1.add_paragraph()
tfp1.font.size = Pt(49)
tfp1.font.bold = False
tfp1.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run1 = tfp1.add_run()
font1 = run1.font
font1.name = 'Dotum'

title2 = slide.shapes.title
tf2 = title2.text_frame
tfp2 = tf2.add_paragraph()
tfp2.font.size = Pt(36)
tfp2.font.bold = True
tfp2.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)
run2 = tfp2.add_run()
font2 = run2.font
font2.name = 'Gungsuh'

#run1.text = '"우리를 도우시는 성령님"'
#run2.text = "\n사도행전 4: 23~31\n(Acts)\n"

run1.text = '"'
run1.text += input("말씀제목(Topic): ")
run1.text += '"'
run2.text = "\n"
run2.text += bibleWhere

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'bible.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 


############4 헌금
title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide10.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide11.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide12.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide13.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide14.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 

title_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(title_slide_layout)
img_path = 'slide15.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) 


prs.save('ver2.pptx')
# Out:
# 찬양(Praise)(장)?: 259
# 기도누구(Prayer): 송관섭 집사
# 말씀본문(Bible): 사도행전 6:8~15절
# 영어표기(English name): Acts
# 말씀봉독자(Reader): 장순영 집사
# 말씀제목(Topic): 우리의 페이스메이커
