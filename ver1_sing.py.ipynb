# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import ColorFormat, RGBColor

'''
praise_path = './찬송가/'
praise_path += input("찬양(Praise)?: ")
praise_path += '.pptx'
'''
'''
praise_path = open('./찬송가/10.pptx', 'rb')
prs = Presentation(praise_path)

prs.save('test3.1.pptx')
praise_path.close()
'''
'''
slide_count = len(prs.slides)
print(slide_count)

for n in range(slide_count):
    slide = prs.slides[n]
    img_path = 'bible.png'
    shapes = slide.shapes
    left = top = Inches(0)
    pic = shapes.add_picture(img_path, left, top) 
    shapes._spTree.remove(pic._element)
    shapes._spTree.insert(2, pic._element) # It makes picture backward


#prs1 = Presentation("./찬송가/6장.pptx")   
#prs = Presentation()

title_slide_layout = prs.slide_layouts[2]
slide = prs.slides.add_slide(title_slide_layout) # add slide

img_path = 'pray.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward

title = slide.shapes.title
tf = title.text_frame
tfp = tf.add_paragraph()
tfp.font.size = Pt(52)
tfp.font.bold = False
tfp.font.color.rgb = RGBColor(0,0,0) # red (255,0,0), blue (0,0,255)

run = tfp.add_run()
font = run.font
#font.name = 'Gungsuh'
font.name = 'Dotum'
run.text = "기도\n\n"
run.text += input("기도누구(Prayer): ")
'''
'''
input_file = open("./찬송가/6장.pptx")
for lines in range(2):
    line = input_file.readline()
    output_file.write(line)
'''

praise_path = "./찬송가/10.pptx"
prs = Presentation(praise_path)

prs.slides.add_slide(prs.slide_layouts[2])

praise_path = "./찬송가/6.pptx"
prs1 = Presentation(praise_path)

img_path = 'pray.png'
shapes = slide.shapes
left = top = Inches(0)
pic = shapes.add_picture(img_path, left, top) # same as slide.shapes.add_picture
shapes._spTree.remove(pic._element)
shapes._spTree.insert(2, pic._element) # It makes picture backward


#slide_count = len(prs1.slides)
#print(slide_count)

#prs = Presentation(praise_path)
prs.save('test3.1.pptx')

#praise_path.close()
